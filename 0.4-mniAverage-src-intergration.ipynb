# %%
#### NOTEBOOK CONFIG ####

# %load_ext autoreload
# %autoreload 2
import os
import sys
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
sys.path.append("/home/carlos/Carlos/cerebra-atlas-python")

####### IMPORTS #######

import mne
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

import numpy as np
from matplotlib.patches import Rectangle


from cerebra_atlas_python.cerebra import CerebrA
from cerebra_atlas_python.plotting import get_cmap_colors
from cerebra_atlas_python.utils import setup_logging, time_func_decorator
from cerebra_atlas_python.MNIAverage import MNIAverage

# %%
setup_logging(level="INFO")
cerebra = CerebrA()


cerebra.orthoview(plot_affine=True, plot_whitematter=True,plot_regions=True, plot_src_space=True)
# Out:
#  [INFO] 2023-11-02 18:04:14.354 MNIAverage - _set_bem: Loading boundary element model from disk | conductivity=0.33_0.0042_0.33 ico= 4
#  [INFO] 2023-11-02 18:04:14.425 MNIAverage - _set_vol_src: Reading volume source space from disk
# array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#        [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object)

# %%
axs = cerebra.orthoview(plot_affine=False, plot_whitematter=True,plot_regions=True, plot_src_space=False,plot_bem_surfaces=True, plot_distance_to_inner_skull=True, pt=[120,120,120])
# Out:
# [104 119  60] 62.10475022089695
# [104 119  60] 62.10475022089695
# [104 119  60] 62.10475022089695
