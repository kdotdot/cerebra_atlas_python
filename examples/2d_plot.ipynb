# %%
from cerebra_atlas_python import CerebrA

# %%
cerebra = CerebrA()
cerebra.plot_2d(plot_affine=True, plot_narrow_ax=False)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Y', ylabel='Z'>)

# %%
cerebra.plot_2d(plot_affine=True, kind="orthoview", plot_narrow_ax=False, figsize=(20,20))
# Out:
# <class 'numpy.ndarray'> True
# (<Figure size 2000x2000 with 4 Axes>,
#  array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#         [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object))
