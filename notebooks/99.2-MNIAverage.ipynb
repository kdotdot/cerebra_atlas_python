# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import mne
import numpy as np
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)

# %%
from cerebra_atlas_python.mni_average import MNIAverage
mni_average = MNIAverage()
# Out:
# Loading surfaces...
#
# Loading the solution matrix...
#
# Three-layer model surfaces loaded.
# Loaded linear collocation BEM solution from /home/carlos/Carlos/source-localization/generated/mni_average/MNIAverage_bem_0.33_0.0042_0.33_ico_4.fif
#     Reading a source space...
#     [done]
#     1 source spaces read

# %%
from cerebra_atlas_python.cerebra import CerebrA, setup_logging
from cerebra_atlas_python.utils import time_func_decorator

setup_logging(level="DEBUG")
cerebra = CerebrA()
# Out:
# DEBUG:root:Value for variable default_data_path not provided in config.ini[CerebrA]. Defaulting to default_data_path=../cerebra_data/cerebra
# DEBUG:root:Value for variable default_data_path not provided in config.ini[MNIAverage]. Defaulting to default_data_path=../cerebra_data
# INFO:root:Using data from SUBJECTS_DIR/MNIAverage
# INFO:root:Loading boundary element model from disk | MNIAverage_bem_0.33_0.0042_0.33_ico_4
# INFO:root:Reading volume source space from disk

# %%
cerebra.orthoview(plot_regions=True,plot_empty=False, plot_bem_surfaces=True, plot_src_space=True)
# Out:
# INFO:root:********** START(orthoview) **********
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cerebra.orthoview(plot_regions=True,plot_empty=False, plot_bem_surfaces=True, plot_src_space=True)
#
# File ~/Carlos/cerebra-atlas-python/cerebra_atlas_python/utils.py:18, in time_func_decorator.<locals>.wrapper_function(*args, **kwargs)
#      16 logging.info(f'{"*" * 10} START({func.__name__}) {"*" * 10}')
#      17 start_time = time.time()
# ---> 18 res = func(*args, **kwargs)
#      19 end_time = time.time()
#      20 logging.info(
#      21     f'{"*" * 10} END({func.__name__}) {"*" * 10} ({end_time-start_time:.2f} s)'
#      22 )
#
# File ~/Carlos/cerebra-atlas-python/cerebra_atlas_python/cerebra.py:202, in CerebrA.orthoview(self, plot_src_space, plot_bem_surfaces, plot_distance_to_inner_skull, **kwargs)
#     200 src = None
#     201 if plot_src_space:
# --> 202     src = self.get_src_volume()
#     204 bem_surfaces = None
#     205 if plot_bem_surfaces:
#
# File ~/Carlos/cerebra-atlas-python/cerebra_atlas_python/cerebra.py:173, in CerebrA.get_src_volume(self)
#     171 def get_src_volume(self):
#     172     if self.src_volume is None:
# --> 173         src_space_ras_nzo = self.mni_average.get_src_space_ras_nzo(
#     174             transform=self.affine
#     175         )
#     176         src_space_ras = self.center_ras_volume(
#     177             src_space_ras_nzo
#     178         )  # Points in RAS coord frame
#     179         # return src_volume
#
# File ~/Carlos/cerebra-atlas-python/cerebra_atlas_python/mni_average.py:246, in MNIAverage.get_src_space_ras_nzo(self, transform)
#     234 def get_src_space_ras_nzo(
#     235     self, transform: Optional[mne.transforms.Transform] = None
#     236 ) -> np.ndarray:
#     237     """
#     238     Retrieves the source space coordinates in RAS with non-zero origin, with an optional transformation.
#     239
#    (...)
#     244         np.ndarray: The source space coordinates in RAS (non-zero origin).
#     245     """
# --> 246     src_space = self.mri_to_ras_nzo(
#     247         self.src["rr"]
#     248     )  # Move volume from MRI space to RAS (non-zero origin)
#     249     if transform is not None:
#     250         src_space = mne.transforms.apply_trans(transform, src_space)
#
# File ~/Carlos/cerebra-atlas-python/cerebra_atlas_python/mni_average.py:232, in MNIAverage.mri_to_ras_nzo(self, pts)
#     224 def mri_to_ras_nzo(self, pts: np.ndarray) -> np.ndarray:
#     225     """
#     226     Converts points from MRI (surface RAS) coordinates to RAS coordinates with non-zero origin.
#     227     Args:
#    (...)
#     230         np.ndarray: Points converted to RAS (non-zero origin) coordinates.
#     231     """
# --> 232     return mne.transforms.apply_trans(self.src["mri_ras_t"], pts) * 1000
#
# KeyError: 'mri_ras_t'

# %%
nib.load(cerebra.cerebra_path).header.get_data_dtype()
# Out:
# dtype('>f4')

# %%
import math

def convert_size(size_bytes):
   if size_bytes == 0:
       return "0B"
   size_name = ("B", "KB", "MB", "GB", "TB", "PB", "EB", "ZB", "YB")
   i = int(math.floor(math.log(size_bytes, 1024)))
   p = math.pow(1024, i)
   s = round(size_bytes / p, 2)
   return "%s %s" % (s, size_name[i])

# %%
cerebra.cerebra_volume.itemsize
# Out:
# 1

# %%
tot = 0
for k,v in cerebra.volume_data_sparse.items():
    tot+=v.itemsize * v.size
    print(k, convert_size(v.itemsize * v.size))
print(convert_size(tot))
# Out:
# 1 63.7 KB
# 2 6.81 KB
# 3 47.53 KB
# 4 1.62 KB
# 5 3.1 KB
# 6 14.74 KB
# 7 44.07 KB
# 8 11.23 KB
# 9 56.64 KB
# 10 76.72 KB
# 11 49.66 KB
# 12 36.22 KB
# 13 53.3 KB
# 14 5.51 KB
# 15 26.03 KB
# 16 24.13 KB
# 17 2.25 KB
# 18 7.93 KB
# 19 4.83 KB
# 20 7.52 KB
# 21 19.41 KB
# 22 24.01 KB
# 23 27.89 KB
# 24 39.47 KB
# 25 576.0 B
# 26 17.88 KB
# 27 4.98 KB
# 28 82.88 KB
# 29 3.22 KB
# 30 10.7 KB
# 31 55.0 KB
# 32 22.48 KB
# 33 12.97 KB
# 34 66.82 KB
# 35 62.67 KB
# 36 9.39 KB
# 37 2.26 KB
# 38 154.74 KB
# 39 38.08 KB
# 40 29.41 KB
# 41 28.04 KB
# 42 38.73 KB
# 43 23.65 KB
# 44 10.66 KB
# 45 74.27 KB
# 46 208.68 KB
# 47 15.85 KB
# 48 13.75 KB
# 49 16.53 KB
# 50 13.18 KB
# 51 46.97 KB
# 52 63.7 KB
# 53 5.63 KB
# 54 47.53 KB
# 55 1.62 KB
# 56 3.1 KB
# 57 14.74 KB
# 58 44.07 KB
# 59 11.08 KB
# 60 56.64 KB
# 61 76.72 KB
# 62 45.54 KB
# 63 36.21 KB
# 64 53.3 KB
# 65 5.51 KB
# 66 25.68 KB
# 67 24.13 KB
# 68 2.24 KB
# 69 7.93 KB
# 70 4.83 KB
# 71 6.21 KB
# 72 19.41 KB
# 73 24.01 KB
# 74 27.89 KB
# 75 39.47 KB
# 76 576.0 B
# 77 17.88 KB
# 78 4.98 KB
# 79 82.88 KB
# 80 1.8 KB
# 82 54.99 KB
# 83 22.48 KB
# 84 12.97 KB
# 85 66.82 KB
# 86 62.67 KB
# 87 9.39 KB
# 88 1.79 KB
# 89 154.74 KB
# 90 38.08 KB
# 91 29.41 KB
# 92 28.04 KB
# 93 38.73 KB
# 94 23.63 KB
# 95 10.66 KB
# 96 74.27 KB
# 97 208.68 KB
# 98 15.53 KB
# 99 13.75 KB
# 100 16.53 KB
# 101 11.61 KB
# 102 46.97 KB
# 103 1.48 MB
# 4.82 MB

# %%
convert_size(cerebra.cerebra_volume.size * cerebra.cerebra_volume.itemsize)
# Out:
# '16.0 MB'

# %%
for k in

# %%
cerebra.orthoview(plot_regions=True)
# Out:
# array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#        [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object)
