# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("/home/carlos/Carlos/cerebra-atlas-python")

# %%
import matplotlib.pyplot as plt
from cerebra_atlas_python.cerebra import CerebrA
cerebra = CerebrA()

fig, axs = cerebra.orthoview()
fig.savefig("../images/orthoview_example.png",bbox_inches='tight')

# %%
fig, ax = cerebra.plot(add_top_left_info=False, add_coordinate_frame_info=False,  add_grid=True, add_ax_labels=False)
fig.savefig("../images/example.png",bbox_inches='tight')
