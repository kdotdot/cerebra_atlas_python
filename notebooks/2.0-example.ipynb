# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import mne
import numpy as np
nb_dir = os.path.split(os.getcwd())[0]
if nb_dir not in sys.path:
    sys.path.append(nb_dir)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from cerebra_atlas_python.cerebra import CerebrA, setup_logging
from cerebra_atlas_python.plotting import  plot_brain_slice_2D, get_cmap

# %%
setup_logging(level="INFO")
cerebra = CerebrA()
cerebra.orthoview(plot_affine=True, plot_whitematter=False,plot_regions=True,plot_src_space=True)
# Out:
#  [WARNING] 2023-11-13 19:29:25.119 config - __init__: Value for variable download_data not provided in config.ini[CerebrA]. Defaulting to download_data=True
#  [WARNING] 2023-11-13 19:29:25.266 config - __init__: Value for variable fs_subjects_dir not provided in config.ini[MNIAverage]. Defaulting to fs_subjects_dir=/home/carlos/Datasets/subjects
#  [WARNING] 2023-11-13 19:29:25.267 config - __init__: Value for variable download_data not provided in config.ini[MNIAverage]. Defaulting to download_data=True
#  [INFO] 2023-11-13 19:29:25.268 mni_average - _set_bem: Loading boundary element model from disk | MNIAverage_bem_0.33_0.0042_0.33_ico_4
#  [INFO] 2023-11-13 19:29:25.339 mni_average - _set_vol_src: Reading volume source space from disk
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 3
#       1 setup_logging(level="INFO")
#       2 cerebra = CerebrA()
# ----> 3 cerebra.orthoview(plot_affine=True, plot_whitematter=False,plot_regions=True,plot_src_space=True)
#
# File ~/Carlos/cerebra-atlas-python/cerebra_atlas_python/cerebra.py:217, in CerebrA.orthoview(self, plot_src_space, plot_bem_surfaces, plot_distance_to_inner_skull, **kwargs)
#     215 src = None
#     216 if plot_src_space:
# --> 217     src = self.get_src_volume()
#     219 bem_surfaces = None
#     220 if plot_bem_surfaces:
#
# File ~/Carlos/cerebra-atlas-python/cerebra_atlas_python/cerebra.py:189, in CerebrA.get_src_volume(self)
#     187 def get_src_volume(self):
#     188     if self.src_volume is None:
# --> 189         src_space_ras_nzo = self.mni_average.get_src_space_ras_nzo(
#     190             transform=self.affine
#     191         )
#     192         src_space_ras = self.center_ras_volume(
#     193             src_space_ras_nzo
#     194         )  # Points in RAS coord frame
#     195         # return src_volume
#
# File ~/Carlos/cerebra-atlas-python/cerebra_atlas_python/mni_average.py:244, in MNIAverage.get_src_space_ras_nzo(self, transform)
#     232 def get_src_space_ras_nzo(
#     233     self, transform: Optional[mne.transforms.Transform] = None
#     234 ) -> np.ndarray:
#     235     """
#     236     Retrieves the source space coordinates in RAS with non-zero origin, with an optional transformation.
#     237
#    (...)
#     242         np.ndarray: The source space coordinates in RAS (non-zero origin).
#     243     """
# --> 244     src_space = self.mri_to_ras_nzo(
#     245         self.src["rr"]
#     246     )  # Move volume from MRI space to RAS (non-zero origin)
#     247     if transform is not None:
#     248         src_space = mne.transforms.apply_trans(transform, src_space)
#
# File ~/Carlos/cerebra-atlas-python/cerebra_atlas_python/mni_average.py:230, in MNIAverage.mri_to_ras_nzo(self, pts)
#     222 def mri_to_ras_nzo(self, pts: np.ndarray) -> np.ndarray:
#     223     """
#     224     Converts points from MRI (surface RAS) coordinates to RAS coordinates with non-zero origin.
#     225     Args:
#    (...)
#     228         np.ndarray: Points converted to RAS (non-zero origin) coordinates.
#     229     """
# --> 230     return mne.transforms.apply_trans(self.src["mri_ras_t"], pts) * 1000
#
# KeyError: 'mri_ras_t'

# %%
cerebra.affine
# Out:
# array([[  1. ,   0. ,   0. , 126. ],
#        [  0. ,   1. ,   0. , 146.5],
#        [  0. ,   0. ,   1. , 109.5],
#        [  0. ,   0. ,   0. ,   1. ]])

# %%
cerebra.orthoview(pt=[166, 109, 52],plot_regions=True, plot_whitematter=True, plot_empty=False, plot_bem_surfaces=True)
# Out:
# array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#        [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object)

# %%
cerebra.orthoview(pt=[120, 150, 190])
# Out:
# array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#        [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object)

# %%
cerebra.get_closest_region_to_whitematter(pt=[120, 150, 190])
# Out:
# (True, array([115, 145, 185]), 89)

# %%
cerebra.orthoview(pt=[115, 145, 185])
# Out:
# array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#        [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object)

# %%
# %matplotlib qt

# %%
cerebra.orthoview(pt=cerebra.voxel_to_ras([50, -77, 3]))
pass

# %%
cerebra.plot_region_orthoview(region_id=35)
# Out:
# array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#        [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object)

# %%
cerebra.orthoview(cmap_name="gray")
# Out:
# array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#        [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object)

# %%
cerebra.plot_region_orthoview(region_id=89)
# Out:
# array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#        [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object)

# %%
cerebra.plot_region_orthoview(region_id=89-51)
# Out:
# array([[<Axes: xlabel='Y', ylabel='Z'>, <Axes: xlabel='X', ylabel='Z'>],
#        [<Axes: xlabel='X', ylabel='Y'>, <Axes: >]], dtype=object)

# %%
# %matplotlib qt
cerebra.plot_3d(alpha=0.1)
# Out:
# restart
# (<Figure size 640x480 with 1 Axes>,
#  <Axes3D: xlabel='X (R)', ylabel='Y (A)', zlabel='Z (S)'>)

# %%
cerebra.plot_whitematter_3d(alpha=0.05)
# Out:
# restart

# %%
1+1
# Out:
# 2
